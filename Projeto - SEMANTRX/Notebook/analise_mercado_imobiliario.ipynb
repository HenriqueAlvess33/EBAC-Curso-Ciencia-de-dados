# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\hfasa\Desktop\Wares\DEV\Estudos\Cientista de dados\Projeto - SEMANTRX\CSV\Base de dados\dados.csv')

# %%
pd.set_option('display.max_columns', None)

# %%
df.head()
# Out:
#    sql_registration_number transaction_nature  transaction_value_declared  \
# 0              13944000322   1.Compra e venda                    264000.0
# 1               6726500084   1.Compra e venda                    800000.0
# 2              13944000322   1.Compra e venda                    203700.0
# 3               5614900926   1.Compra e venda                    264000.0
# 4              13944000322   1.Compra e venda                    200550.0
#
#       transaction_date  reference_market_value  transmitted_proportion  \
# 0  2022-12-22 00:00:00              15828870.0                    0.20
# 1  2022-12-23 00:00:00                846885.0                  100.00
# 2  2022-12-22 00:00:00              15828870.0                    0.01
# 3  2022-12-22 00:00:00               3403192.0                    0.08
# 4  2022-12-22 00:00:00              15828870.0                    0.01
#
#    proportional_reference_market_value  adopted_calculation_base  \
# ...

# %%
df['transaction_nature'].value_counts()
# Out:
# transaction_nature
# 1.Compra e venda                                                           157449
# 12.Dação em pagamento por escritura pública                                  3925
# 20.Realização ou integralização de capital                                   3496
# 17.Resolução da alienação fiduciária por inadimplemento                      1980
# 2.Cessão de direitos relativos a compromisso de compra e venda               1585
# 4.Arrematação (em leilão ou hasta pública)                                   1581
# 15.Permuta por escritura pública                                             1303
# 3.Adjudicação (vinculada a processo de execução ou cobrança de dívida)        810
# 26.Cessão de direitos sobre o imóvel com alienação fiduciária                 550
# 5.Adjudicação compulsória                                                     459
# 29.Excesso de meação na partilha (separação / divórcio)                       423
# ...
