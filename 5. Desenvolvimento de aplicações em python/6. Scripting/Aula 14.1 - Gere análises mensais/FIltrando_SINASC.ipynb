# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt


sns.set_theme()

# %%
sinasc = pd.read_csv('./input/SINASC_RO_2019.csv')
sinasc.head()
# Out:
#    ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 0       1  2679477.0      110001        1        19        5.0
# 1       1  2679477.0      110001        1        29        2.0
# 2       1  2679477.0      110001        1        37        9.0
# 3       1  2516500.0      110001        1        30        5.0
# 4       1  2516500.0      110001        1        30        2.0
#
#             ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 0      8 a 11 anos         NaN         0.0         0.0  ...           5
# 1      8 a 11 anos    999992.0         1.0         0.0  ...           5
# 2      8 a 11 anos    513205.0         2.0         0.0  ...           5
# 3  12 anos ou mais    231205.0         0.0         0.0  ...           4
# 4      8 a 11 anos    999992.0         1.0         0.0  ...           5
#
#   CONTADOR munResStatus munResTipo               munResNome  munResUf  \
# 0        1        ATIVO      MUNIC    Alta Floresta D'Oeste  Rondônia
# ...

# %%
sinasc['DTNASC'] = pd.to_datetime(sinasc['DTNASC'])
sinasc_janeiro = sinasc[sinasc['DTNASC'].dt.month == 1]
sinasc_janeiro
# Out:
#        ORIGEM   CODESTAB  CODMUNNASC  LOCNASC  IDADEMAE  ESTCIVMAE  \
# 72          1  6663834.0      110002        1        29        2.0
# 73          1  6663834.0      110002        1        25        2.0
# 74          1  2515601.0      110002        1        35        2.0
# 75          1  2515601.0      110002        1        24        2.0
# 76          1  2515601.0      110002        1        26        1.0
# ...       ...        ...         ...      ...       ...        ...
# 13726       1  2012480.0      130260        1        26        5.0
# 13728       1    26794.0      310620        1        31        2.0
# 13729       1  7257406.0      320500        1        25        2.0
# 13735       1  2089602.0      355030        1        33        2.0
# 13745       1  2604388.0      510340        1        36        5.0
#
#                 ESCMAE  CODOCUPMAE  QTDFILVIVO  QTDFILMORT  ...  KOTELCHUCK  \
# 72     12 anos ou mais    999992.0         0.0         0.0  ...           5
# ...

# %%
sinasc_janeiro.to_csv('./input/SINASC_RO_2019_JAN.csv')
